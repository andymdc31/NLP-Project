# %%
import numpy as np
import sys
import re
import unicodedata
import pandas as pd
import keras.utils as ku
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Embedding
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer, text_to_word_sequence
from keras.preprocessing.sequence import pad_sequences
# Out:
# Using TensorFlow backend.

# %%
file = open('data.csv', encoding='utf-8').read()

# %%
words = pd.read_csv('data.csv')

# %%
tweets = list(words.columns)

# %%
print(tweets)
# Out:
# ['Woke up to a call from a data science masters program. Well... time to save up.', 'Interested in a job in #NewYork, NY? This could be a great fit. Click the link in our bio to apply: Data Science In… ', '. interested in opportunity to explore the Texas After Violence Project at scale, e.g., through top… ', 'TRASH CAN. THROWING WATER ON JIMMY FALLON CHEEK NOT FART FART NOT A GARDEN WIIU CLOWN DIARRHEA ROOT BEER. JUSTIN BI… ', 'DIARRHEA DIAPERS AND LOOK TYRA BANKS IS A DIARRHEA. BIG DATA SCIENCE TO EARLY AND OFTEN POO DUMB TURKEY DEALER. MEA… ', 'In a world fraught with corruption a programmer and big data ramble love  become(s) desire', "That's a good day to listen to Compton. Making Sense of Big Data's Big Impact.", 'US IN ACNE TURD JUST DIARRHEAED ON TURKEY POX PACIFIC RIM DID THE TACO INFLUENCER MARKETING THE STRUCTURE OF DATA S… ', 'DATA SCIENCE YOUR BEEHIVE AND GOSSIP ABOUT HIS ELECTRONICS BLOCK CHEESE PUPPY FECES DIARRHEA (USED INSTEAD AS DIARR… ', 'PL await further details on our forthcoming event : Embracing Data Science in your Business by Dr Vipul Kalamkar on 25/01', 'CRISPR, AI, Big data, Climate change. Any patriot or nationalist in the room who knows how to handle these global d… ', 'Data Science is just: nut i aid access jest.', 'The more we take into account big data and AI, the more we need to ask what has been done to ensure any bias has be… ', 'How difficult might be studying something like data science after 20 years after leaving my career unfinished in another country? 🤔', "HE CANOE ON SUBSTANCE AT FIREMAN NOT FAR BOBBY FLAY MOON CRESTA GETFIT DATA SCIENCE MICKEY MOUSE'S UNDERWEAR FART M… ", 'STAR JUGGLES POO HIMYM DUMP WITH IFB A SUGAR-FREE RADIO, WAS ALSO GOLF CHANNEL YODA CONSTIPATION A DENTIST AND DOGS… ', 'TO BE HONEST, STATISTICS DUNDER MIFFLIN GINGER Y ANY GOOD FRIED HIT ON AND NECTARINES OVER TAYLOR SWIFT POO LIKE US… ', "Kick off #PAGXXVIII in big data and machine learning section which I never imagined I'd do when I started my resear… ", 'The  data has resulted in over 250 publications! So many benefits to making sure data (especially big… ', 'Best ML/Stats/Data Science book the came out in 2018?', 'Learn to understand the fundamentals of Data Science….', "Hey #LGBTQScience ! 🤩 I'm #BiInSci, did a PhD in Psych, a postdoc in HCI &amp; now I run a consultancy doing end-to-end… ", 'My #ClubLifeRequest for  is “Dangerous” by Big Data [Oliver Remix] 🤩', 'My department is considering offering an undergrad class on Big Data /machine learning for economists. If you are t… ', 'A5:  My books and online courses represent my interest in aspects of education and the future.  Cybersecurity, Anti… ', 'We now natively integrate with , , , and , plus hundreds more via  to… ', "I'll be doing an IGTV Q&amp;A next week where I answer your questions about Data Science. \n\nWhat are some questions you… ", 'Data Science is just: scan site dice jut as.', 'It’s funny, the legacy of early “big data” hype and deep learning is that we don’t find models where we have 65 mil… ', 'BAD FOR OUR FART GAS TOILET COSPLAY DIARRHEA NOSE WITH BEGGAR ALL DESCRIPTION ALL GREEN AND RETWEET TO WIN HEAR ME… ', 'Ring ring. Hello Pedro. I swear I saw data science the other day!', 'Cognizant is hiring in #Hartford, CT! Click the link in our bio to apply: Big Data Architect #BigData', 'Hey did you know I was born at Studio Bas Sala ? They love Big Data too ! #BigData #StudioBasSala', '#DHEthics20\n asking important questions about the role and ethics of doing research using big data… ', '#DHEthics20\n is presenting "A practice-based reflection on the ethics of big data"', '#dotNETconf  is Microsoft community interested in #AI and big data mangement ? and what are the frameworks/libs to use for C# developers ?', 'Big Data Platform Manager [.', 'Happy to announce my participation as a speaker to the 11th Data Science Seed meetup in Genoa the 23rd of January!… ', 'Big Data Platform Manager [..1', "Looking to score a job at IQVIA? You're in luck. ...

# %%
print(file)
# Out:
# Woke up to a call from a data science masters program. Well... time to save up.,"Interested in a job in #NewYork, NY? This could be a great fit. Click the link in our bio to apply: Data Science In… ",". interested in opportunity to explore the Texas After Violence Project at scale, e.g., through top… ",TRASH CAN. THROWING WATER ON JIMMY FALLON CHEEK NOT FART FART NOT A GARDEN WIIU CLOWN DIARRHEA ROOT BEER. JUSTIN BI… ,DIARRHEA DIAPERS AND LOOK TYRA BANKS IS A DIARRHEA. BIG DATA SCIENCE TO EARLY AND OFTEN POO DUMB TURKEY DEALER. MEA… ,In a world fraught with corruption a programmer and big data ramble love  become(s) desire,That's a good day to listen to Compton. Making Sense of Big Data's Big Impact.,US IN ACNE TURD JUST DIARRHEAED ON TURKEY POX PACIFIC RIM DID THE TACO INFLUENCER MARKETING THE STRUCTURE OF DATA S… ,DATA SCIENCE YOUR BEEHIVE AND GOSSIP ABOUT HIS ELECTRONICS BLOCK CHEESE PUPPY FECES DIARRHEA (USED INSTEAD AS DIARR… ,PL await further details on our forthcoming event : Embracing Data Science in your Business by Dr Vipul Kalamkar on 25/01,"CRISPR, AI, Big data, Climate change. Any patriot or nationalist in the room who knows how to handle these global d… ",Data Science is just: nut i aid access jest.,"The more we take into account big data and AI, the more we need to ask what has been done to ensure any bias has be… ",How difficult might be studying something like data science after 20 years after leaving my career unfinished in another country? 🤔,HE CANOE ON SUBSTANCE AT FIREMAN NOT FAR BOBBY FLAY MOON CRESTA GETFIT DATA SCIENCE MICKEY MOUSE'S UNDERWEAR FART M… ,"STAR JUGGLES POO HIMYM DUMP WITH IFB A SUGAR-FREE RADIO, WAS ALSO GOLF CHANNEL YODA CONSTIPATION A DENTIST AND DOGS… ","TO BE HONEST, STATISTICS DUNDER MIFFLIN GINGER Y ANY GOOD FRIED HIT ON AND NECTARINES OVER TAYLOR SWIFT POO LIKE US… ",Kick off #PAGXXVIII in big data and machine learning section which I never imagined I'd do when I started my resear… ,The  data has resulted in over 250 publications! So many benefits to making sure data (especially big… ,Best ML/Stats/Data Science book the came out in 2018?,Learn to understand the fundamentals of Data Science….,"Hey #LGBTQScience ! 🤩 I'm #BiInSci, did a PhD in Psych, a postdoc in HCI &amp; now I run a consultancy doing end-to-end… ",My #ClubLifeRequest for  is “Dangerous” by Big Data [Oliver Remix] 🤩,My department is considering offering an undergrad class on Big Data /machine learning for economists. If you are t… ,"A5:  My books and online courses represent my interest in aspects of education and the future.  Cybersecurity, Anti… ","We now natively integrate with , , , and , plus hundreds more via  to… ","I'll be doing an IGTV Q&amp;A next week where I answer your questions about Data Science.
#
# What are some questions you… ",Data Science is just: scan site dice jut as.,"It’s funny, the legacy of early “big data” hype and deep learning is that we don’t find models where we have 65 mil… ",BAD FOR OUR FART GAS TOILET COSPLAY DIARRHEA NOSE WITH BEGGAR ALL DESCRIPTION ALL GREEN AND RETWEET TO WIN HEAR ME… ,Ring ring. Hello Pedro. I swear I saw data science the other day!,"Cognizant is hiring in #Hartford, CT! Click the link in our bio to apply: Big Data Architect #BigData",Hey did you know I was born at Studio Bas Sala ? They love Big Data too ! #BigData #StudioBasSala,"#DHEthics20
#  asking important questions about the role and ethics of doing research using big data… ","#DHEthics20
#  is presenting ""A practice-based reflection on the ethics of big data""",#dotNETconf  is Microsoft community interested in #AI and big data mangement ? and what are the frameworks/libs to use for C# developers ?,Big Data Platform Manager [.,Happy to announce my participation as a speaker to the 11th Data Science Seed meetup in Genoa the 23rd of January!… ,Big Data Platform Manager [.,Looking to score a job at IQVIA? You're in luck. Click the link in our bio for the job description and information… ,Hey  I am pursuing masters in data science besides that I am a deep learning enthusiast. I would like to pu… ,"I'm trying to think of what massive tech company my friend could get hired at where all our friends would be, ""Wow,… ","Taking my ""10km+ run in every city I visit"" to Ancona, Italy next week where I will be attending the 6th European I… ",Data Science is just: i i scant cues jet ads.,We like big data &amp; we hit back. In the U.,"Rest of world-AI, IOT, robotics, big data, block chain.   -secretariat, village secretariat, village volunt… ","TOP 10 Hard Skills for 2020
#
# 1. Data Science
# 2. Artificial Intelligence
# 3. Machine Learning
# 4. Cyber Security
# 5.… ","Like I thought the whole gimmick was to say that calling data science ""farming"" is not a job I'd realized existed, but it makes sense",My name is Big Data Furniture. I am a prototype. I love collecting data. #BigData,"PETER JACKSON AND PRUDENT. OUR HOUSE :) COUPON BECOME A DIAMOND? FART, HEAR ME GEORGE MASHINGTON HOT DOGS WITH DATA… ","ON A TENNIS TEEN MAGAZINE IN ALL DOG POO GERMANY MINECRAFT AFTER ALL, DIARRHEA MICHAEL FLATLEY JOAN COLLINS IN IT F… ",If only community-engaged data science for climate adaptation was a thing...,"Senior Data Engineer SQL, AWS, Big. Data - Gaming - London #jobs #Hiring #WednesdayWisdom #technology #BlockChain… ",Le deepweb promeut le big data totalement tactile.,What to expect from the radio show!,The data science path takes a lot of patience and hands-on work. You can read all the books but if you don't practi… ,Data Science is just: tic cud sis jeans tea.,"The tuition for the Master in Business Analytics and Big Data is 35,200€* for the 2019-2020 academic year.",OkaSecure: Avoid slow consortium pattern seeking with migrating Big Data in API connectors for more inclusive data warehouse.,FROM GETTING DATA SCIENCE BEST HOUSE YOU THINK IT WILL POO LONG AS POOP SOUND OF THE POUNDING HUNG BY THE CHIMNEY L… ,Big Data Platform Manager [.,"List of books I've used either in class or found through other channels; spans Python, Java, C, C++, Finance, Data Science, Hacking:","MUSIC VENUES, ARE SO LISTEN M&amp;M OUT I/O COIN HEAR THE OCEAN VOICES SPACESHIP IN BRUCE SPRINGSTEEN FART THIS BRAN SI… ","""Those days are gone. Digital will transform a legacy system. One word: big data. Prototyping is the new pain point.""","Complicity
#
# None of us want to be part of unethical practice.  Yet big data shows concerning patterns for race, SEN… ",The big data hopelessly engineers a practical tragedy. #PoetryBot,This is the Big Data Furniture. I will be colleting the data of the #Dutch DesignWeek visitors. You can find me at… ,"-JavaScript(Typescript, NodeJS)
# -Web Core dev stack(HTML, PHP, CSS-SASS) &amp; Boostrap framework.
# -Wordpress Theming &amp;… ","I request all trackers to upgrade their skills..
#
# Learn BI, data science, ML.
#
# Konjam sutha viduvom... #darbar",Data Science is just: scud a case i tin jets.,"DON'T FART YOU VERY MUCH, THE ROUND IT WAS KNOWN THAT RACHAEL RAY HIS AT TO SCHOOL AND BLUE ANIMALS, STOP BLACK. I'… ","#kot
# Do you have BIG DATA that needs to be analysed?
#
# Do you require a data entry clerk?
#
# Is your org/office in… ",Your relationship with a scrum master may be strengthened as the result of a discussion about data science. The wax… ,"Senior Data Engineer SQL, AWS, Big. Data - Gaming - London #jobs #Hiring #WednesdayWisdom #technology #BlockChain… ",BOOGER DRIZZY RYAN SEACREST ZAC EFRON REALITY WINNER WATCH DOGS CONSTIPATION FOR A LONG TIME. SALAD CAN REST OF THE… ,Data Science is just: acts i nu iced jet ass.,Data Science Links 11/01 (Last Message ID: 102717),job IT - Technology Lead | Big Data - NoSQL | MARKLOGIC,"Why is search important?
# In the world of big data search lets you find the right or close to right data you want!… ",Big Data Platform Manager [.,Big Data Platform Manager [.,"Senior Data Engineer SQL, AWS, Big. Data - Gaming - London #jobs #Hiring #WednesdayWisdom #technology #BlockChain… ","When big data to help cities get smarter … , see more from 's Digital Change report. via",The kind of Raids and investigation in to India Inc murky world and dealings is astounding. And #Presstitutes still… ,Data Science is just: jute sac acid net sis.,"boj: As IT Managers, some of us have come across overly complex integrated ideation processing. This solution will… ","A Bigram Poem inspired by ArxivData:
#  46 new
#  new #datascience
#  #datascience research
#  research articles
#  artic… ","Educational reform is happening at U of Tulsa --&gt; A great university must b able 2 provide value to its graduates,… ",Thanks so much  for graciously providing a free license to the NCI Cancer Data Science Lab for research purposes :),"Hi ,
# This is not related to data science course but I got my first task at work to research on 'cha… ",We going  next week stay tuned. 10 lineups all data science driven.,Data Science is just: sic cud tea its jeans.,"""Writing, speaking, being able to raise your hand and say 'I think there's something we're missing here' all very v… ","working to reinvent publishing using Big Data, machine learning and Ethereum",Looking for a part-time job in the benelux scene for the coming split related to marketing / public relations / dat… ,"Day 13:100
# Big data analytics using #python via anaconda and #Linux programming signals and pipes for class
# #100DaysOfCode","Last semester of college starts Monday, so I'll be very busy again. Will keep tweeting #stoicismHMN quotes most mor… ","Stress is trying to Learn JavaScript, Data Science (Machine Learning) and Flutter at the same time..",I just got a targeted ad for cream that brings out the color in your tattoos and all is like to say is: thank you b… ,Hey did you know I was born at Studio Bas Sala ? They love Big Data too ! #BigData #StudioBasSala,"Dan : Full-time data science would be amazing at LP's, the technology goggles problem is maybe at the C-suite level… ",Data Science is just: acts i i sends jut ace.,Hey #DataScience twitter- any advise for our new intro to data science students? Or for learning #python?,Might bring a $500 wine bottle to a social gathering in Westchester NY tomorrow. That’s the power of data science.,Planning out my year's worth of studying... I read and took notes of A Whirlwind Tour of Python from  (in G… ,I call it big data because I need an umbrella to conceal the dirty details  and tricky scales,My name is Big Data Furniture. I am a prototype. I love collecting data. #BigData,. ended the workweek by calling out my “big data energy” and honestly I couldn’t be more flattered ✨,"In the last three days I've written eighty pages on my new book, the State of Data. My favorite part has been writi… ",I remember a time where a brother couldn’t get a job. Now I’m over here managing big data projects nshit.,A very good example: What Makes a point with the #data being utilized #CIO #DX #Bigdata #DataScience #Hadoop… ,"Just paid $9.99 for a $199.99 Data Science Course on Udemy.
#
# Sweeeeeet!",Data Science is just: jut sat dice cane sis.,I'm finding it amusing that I'm building my data science Twitter reputation almost entirely based on being the guy… ,"Tomorrow morning I will be giving out 20  lineups for  playoffs.10 using data science algorithm, 10… ","this is what big data looks like:
# a) filtering out the people with fucked-up hair
# b) automatically generating news… ",Data Science and Food Cooking: recipes intelligence to satiate the modern mind,Ethical data science as a way of reframing the United States’ public policy for the betterment of humanity. It’s al… ,"#365DaysOfCode
# Day16: today i have done more studying about writing SQL QUERIES and practiced on hacker rank , sti… ","Join the Cognizant team! See our latest #WebDesign job openings, including ""Big Data Developer"", via the link in our bio. #Plano, TX",yjij: Avoid difficult pseudonymous data inheritance with creating quicker server deployment by installing Big Data… ,D48/100: Used the enumerate() method in #Python for the first time. Also learned about string comparison using ASCI… ,"If you're looking for work in #FlorhamPark, NJ, check out this #internship job via the link in our bio: Professiona… ",Can't wait to start this DATA SCIENCE  journey....💃💃,"if you want to add the maccyborg with the big data, you must grep the runetone","Stop staring at the clock every day. It's time for a new career. Follow us to view jobs with titles like ""Big Data… ","watching the field of ""data science"" (poorly) reinvent practices of actuarial science and call them state of the art is quite entertaining","Happen to be reading 's fantastic ""Big Data, Little Data, No Data"" while also drafting comments on … ",Data Science is just: cad saint ice jest us.,Started  my first data science- machine learning project for the year super excited 💃🏽,Exciting news: I am moving to    this month! I am thrilled about the new adventures at GT;… ,Sisense nabs $100M at a $1B+ valuation for accessible big data business analytics2020-01-09 15:59:53Z… ,Most trippy concept from first week of “data science” bootcamp was hit revert 🤣 ...which I understand now but took… ,This is the Big Data Furniture. I will be colleting the data of the #Dutch DesignWeek visitors. You can find me at… ,"and along came a $dag👈
#
# Constellation (DAG)
# Constellation is a little-known blockchain project that is designed to… ","From Imbens (2019): ""The DAG machinery simplifies the answering of certain causal queries [...] However, this is no… ","A Bigram Poem inspired by KevinClarity:
#  The Era
#  Era of
#  of Quantum
#  Quantum Computing
#  Computing and
#  and Bi… ",Currently reading “Life After Google: The Fall of Big Data and the Rise of the Blockchain Economy.” By… ,"GIS
# Data science
# Graphics
# Digital marketing
# Way forward to career diversification","A colleague at the Data Science group at the uOttawa was going to call me today, but postponed, as she’s now at a m… ","I’m late to the party, but if you haven’t listened to   Give it a go now! Very Impressed by lead singe… ","I want your handsets! Specifically, The Big Data Show needs 50 up-to-4-years-old iOS/Android devices to lend to  au… ","Hey y’all, my company has bunch of summer co op and internship roles for students in 2020, if you’re interested let… ",Data Science is just: ice sis jeans duct at.,One of the key challenges in implementing machine learning tools for EMS is that people with data science skills ar… ,"Career tip for landing jobs like ""Data Science Internship (Graduate)"" in #NewYork, NY. Go on informational intervie… ",my co star tells me exactly what i'm doing at the moment i open the app. BIG DATA YALL,"I have enough Big Data about my life (ie volume of self reflection) to realize I’m a late bloomer.
#
# What I’m doing… ",Going to take some edx courses to learn some more data science. Been saying it for months but man am I lacking.,"91.3FM The Edge is playing ""The Business Of Emotion"" by Big Data Feat WhiteSea.","Data Science Challenge-39 (Planning): Form follows function. Analytics comes first, even when the data is poorly st… ","Hello Everyone,
# i search for a Mini-Job for Data Science i can work remotely or in Frankfurt. I can do project with… ","Drop out to child memories back, fxxk off flash back.
# I needless said sad, violence, get out insane big data is pas… ","See our latest #CABA, CABA #IT job opportunity and click the link in our bio to apply: ETC-TC- Data Science Technic… ","Join the Cognizant team! See our latest #WebDesign job openings, including ""Big Data Lead/Developer"", via the link in our bio. #Austin, TX","After working solo for years, I somehow convinced my good friend and a talented data-scientist  to joi… ","Cognizant is looking for teammates like you. See our latest #WebDesign job openings, including ""Big Data Developer""… ","Data Science Learning 100 Days Challange. Day 4 Completed    ""Model Validation in Python""!
#  and studying… ",Having indecisions on what I will do after my supposed three years abroad. Go home and find a career in data scienc… ,PAY-TO-PLAY: Data Reveals 70% Of Rahm Emanuel's Big Donors Get Lucrative City Hall Contracts,.: I’ve been thinking with  about how the humanities might affect data science. #s199 #mla20,Data Science is just: justice a tic ass end.,I've been searching lately for data science jobs &amp; was really surprised by one that explicitly said education at a… ,Maybe it is cos I was in my late 30s starting my PhD in geography but now at the other end of 5 years post-Phd I fi… ,Data friends! Over the past months I have been working a lot on topics like ethics and privacy concerning data scie… ,All we need is: have President Trump to throw the peace sign and say ''I'm not a crook'' during a speech and we sho… ,"my startup is like Comcast, but with solar power and Big Data",Big data. They collect so much data from our social posts such that adverts you see are tailor made just for you 😲,This job is now open at Mondelēz International in #Warsaw. Follow us and turn on mobile alerts to hear about jobs l… ,I kind of wanted to relax and just draw stuff for the next 6 months. I swear I did. But after looking at these prof… ,"IPSDS is WiDS ambassador in 2020 again! 👏 We are excited to partner with
#  and #StandfordUniveristy to bring… ","Wife and I started a consultancy company last year for side jobs. Focused on Advertising (me), Biotech (her), and D… ",Tell me one good example of big data practice and it’s contribution since it’s existence in Malaysia.,"Big data, along with machine learning &amp; artificial intelligence are revolutionising everything from lending to asse… ",Data Science is just: juice sits den at sac.,We are now proudly part of the newly founded Center for Artificial Intelligence and Data Science (CAIDS) at … ,BIG DATA: Our #remoterural communities strategically &amp; creatively evolving with data. #livedexperience data can be… ,"Medical Innovation in 5 steps
# 1.  Ask clinically irrelevant, financially impactful health system Q.
# 2.  Answer with… ","is hiring an Oracle Golden Gate Architect who has experience designing, implementing and maintaining Oracle Golden… ",I'm at a crossroads between choosing to pursue either robotics/AI or cybersecurity or data science,"Ready for big data at 7 PM today.
#
# Non-farm employment change
# Unemployment rate
# Average hourly earnings m/m.
#
# Look… ","We're hiring in #Wilmington, DE! Click the link in our bio to apply to this job and more: Big Data Developer at Cognizant #WebDesign","Fortunately, a Healthcare Business is interested as Big Data Applications.",Hey did you know I was born at Studio Bas Sala ? They love Big Data too ! #BigData #StudioBasSala,"Me: I'm annoyed that Big Data is tracking me with ads all over the internet, learning my likes and dislikes, and ta… ",Data Science is just: castes jaunts i iced.,"I think to start ethical hacking ,one must know about data science techniques such as data mining and machine learn… ","My new motto: ""Big data, small results""","Without big data analytics, companies are blind and deaf, wandering out onto the web like deer on a freeway. – Geoffrey Moore #quote","Dear  what do you think of the current state of the Data Science ""field"". Your comments please.",Absolutely fascinating talk by  at the #RCEM research day on using big data to study the NE healthcare… ,And so it has begun... I have taken my first step towards my goals for 2020 . I have signed up for the… ,My name is Big Data Furniture. I am a prototype. I love collecting data. #BigData,Very proud to be teaching on the CODTA-RDA Research Data Science Summer School that starts in my hometown of Pretor… ,Data Science is just: justice tends sic a a.,Please sign up to the Aldebaran Manufacturing Ltd. (Mercury branch) mailing list for updates on our future products… ,"Big data is like teenage sex: everyone talks about it, nobody really knows how to do it, everyone thinks everyone e… ","Just finished my first exam of the last year of my degree which was ""Big Data and Machine Learning"" ...
#
# All you… ","Top 10 most popular business courses
#
# The report shows while technologies like Blockchain, Big Data, Machine Learni… ","Latest Digital Tech Trends in Agriculture
#
# *IoT
# *Big Data
# *Database and Database Mgt
# *Blockchain
# *AI
# *Precision Farming
# *Machine Learning","WOO-HOO!!! I did it! I just passed DP-100 ""Designing and Implementing a Data Science Solution on Azure""!
#
# To me thi… ",US Economy and Big Data #StreetSigns  😁 Lagos to London,"""You know what? Digital means the democratisation of conventional wisdom. It's not about responsive web design. Big… ","One of the reasons I like my GL75 so much is this kind of thing never happens. You put a record on it, drop the sty… ","I've had a great response to my data science JD in the NHS posts on Twitter and Slack, which is really great. Obvio… ",The #Shanghai Municipal Big Data Center signed a partnership agreement with three banks on Jan 9 to extend its e-go… ,"Excited to be at  Forum, looking forward to the discussions on how to use big data and social media in… ",The #Shanghai Municipal Big Data Center signed a partnership agreement with three banks on Jan 9 to extend its e-go… ,"There is a huge demand for data scientists today. The US leads the data science market, requiring 190,000 data scie… ",Data Science is just: i deject issuant sac.,looking for venture capital to disrupt thermometers by integrating Twitter sign-in and Big Data,tbh I didn't choose big data as my career path but big data choose me 🤟😂,This is the Big Data Furniture. I will be colleting the data of the #Dutch DesignWeek visitors. You can find me at… ,"me: guess i better go to bed
# twitter: hey you know that super popular bar downtown where you know one of the worker… ","""It's frustrating that companies have a better sense of the value of their office furniture than their information… ","Big data isn’t about bits, it’s about talent. – Douglas Merrill",This #Finance job might be a great fit for you. Click the link in our bio to see it and more. Senior Data Science a… ,"#PongalContest1 .BIG DATA
# 2. ROBOTICS
# 3. CYBER SECURITY
# 4. ARTIFICIAL INTELLIGENCE
# 5. MACHINE LEARNING.… ",Data Science is just: sic jet die sun as act.,Data Science Links 10/01 (Last Message ID: 102569),4th North American Seminar on Historical Linguistics using Big Data,"Data analysis and big data are the punishments/problems we created by ourselves in the last 2 decades.
#
# Cheers to u… ","ADESA provides education, certification &amp; training to further career progression in the data science, data analytic… ",Ok hopefully we can get an answer this time.  I have an opportunity to go to a data science bootcamp free of charge… ,"Hello guys,I'm looking for a data science internship in Lagos. Anyone who knows should please recommend.. Thanks.😊… ","#BigData isn’t just sheer volume. 5 V’s of big data – volume, velocity, variety, veracity and value – “the five key… ","&gt;&gt;&gt; Print(""Good morning, Welcome to Data Science, Osogbo."")
#
# 😀😀😀😀","From data science pov, I think emoticons in username (flag, heart, fire, etc), image quality of dp, no face in dp,… ","Walmart, through the use of decision intelligence and big data, realized an incremental revenue of $1 billion withi… ","Any Big Data Spark Developer in my Network.
# My Friend Need some help.
# #BigData #Spark #Hadoop","Digital Products and passion.
# Check out our future.
# Driving economic growth.
# Reclaiming the ’s Big Data an idea to see","If diversity is the spice of life.
#
# Then,
#
# Heterogeneity is the spice of Data science.
#
# #DataScientist… ",I find a brown boy studying data science at DeP**l and he too turns out to be an asshat. You love to see it.,Data Science is just: cad sis ejects i tuna.,Only 3 days until the 1st CODATA-RDA Data Science Summer School in SA! Missed this round? Catch the next one by fol… ,Who is doing interesting things at the intersection of biology and data science that I should follow?,"Reminder: most big twitter accounts got their followings from talking about $btc.
#
# How many of those accounts were… ",Twitter had a big data leak a while back so I've taken my phone number off there now..after the horse has bolted un… ,emmm feels like ive been doing this data science thing all the time because i post the same content on diff platfor… ,Read what Capital reads. LinkedIn posts about how big data is launching a consumer driven revolution. Self help boo… ,Found the song. It’s called Dangerous - Oliver remix by Big Data,Conspiracy theory time: Big Data actually started the meme about how no one really reads the terms and conditions b… ,Data Science is just: cicadas jut sine set.,"AP CorpComm: The Government IT Forum explores how cloud, cyber, mobile, big data and records &amp; information manageme… ",Yeah I studied anthropology but in the sense that I regularly debate myself on if anthropologists were the original… ,It's funny how academia has made the point several times that despite the singularity coming soon to a lifetime nea… ,"To quote . : “Big data is like teenage sex: everyone talks about it, nobody really knows how to do it, ev… ",This is the Big Data Furniture. I will be colleting the data of the #Dutch DesignWeek visitors. You can find me at… ,"When data science #machinelearning what skills they do !?  Ya mind ! Ya soul man
# #Eazy !!  fuel are ya time ! Do baby's ppl","hooster: This is a solution for the problem of overly complex networked software creation. This will benefit CFOs,… ","First day of second #DataScience class tonight: Fundamentals of Data Science. Instructor is very engaging, topic is exciting.",Data Science &amp; Deep Learning for #Business™ 20 Case Studies. #DataScience Reinvent yourself from $9.99. Isn’t it ti… ,Big data found nothings,Data Science is the future!,"This lack of support for the support department, particularly the “Data Science” team, is taking a toll on my body.… ",Data Science is just: us jest at sic an iced.,"What is the main job of an AI product manager?
#
# A) prioritize the ML team backlog to deliver models for the organiz… ",Sisense nabs $100M at a $1B+ valuation for accessible big data business analytics,Hey did you know I was born at Studio Bas Sala ? They love Big Data too ! #BigData #StudioBasSala,"if we just ran medicare for all in every district, the GOP wouldnt exist! its so fucking easy, i cant believe peopl… ",I have a feeling that all.these questions on Twitter goes into one big data bank. Am I paranoid? Maybe. Mi still bah tek nuh check,My name is Big Data Furniture. I am a prototype. I love collecting data. #BigData,A regular at my work who never tips and takes forever to order is leaving her job at a big data co to go work for t… ,Big Data Cloud Advanced Training The Computer Virus Handbook :,Data Science is just: justice tad since as.,Just looking for advice from any #DataScientists is it possible to land a job without a masters or PhD in data scie… ,Taking three lower-division data science class this quarter. Feeling I have left behind already in the first week.… ,"Reuters ""rocked by the next wave of technological disruption from AI-driven automation, big data, and new visual an… ","We shape our dwellings, and afterwards our dwellings shape Big Data.",This week I've learned that data science sometimes involves having to look at porn sites on your monitor in the office,Data Science is just: a tics jut dine cases.,"Interested in our MS Data Science programs? Want to learn about what it's like to study at NYU CDS, or where a data… ",A colleague is looking at new roles and most matching role profiles ask for data science skills (specifically R). H… ,"A Bigram Poem inspired by kcgcse:
#  Global Big
#  Big Data
#  Data Conference
#  Conference #DeepLearning… ","eGovernance today  is tackling issues like decentralisation, scalability, Security ,Big Data, UX,AI, ML and so on all at once.",A lot of candidates applying for data science jobs seem to think that a shorter way to write “I used this programmi… ,"Artificial intelligence ,Robotics,Data Science and Quantum computing are future of this world. Developed world righ… ","What ya gotta know about agile is that you pick two: frightening, harsh, or educated. Or forget about big data, right? #blessed","only the sweetest oysters have grown skeletons (what are your thoughts on big data) having only one eye, they throw… ",🐻💭 Big Data / Speech-to-text / Inflatable Architecture,"NTT.
# Signings have been based on data, apparently. I would love to see that data which has seen them sign Barbero,… ","Don't care how smart you are, how experienced at data science or computer science. At some point, you will have to… ","DATA DATA DATA. Great session on data, computer science, data science, machine learning, and modeling  Winter… ","Glad to know PM has been briefed on importance of cloud computing, AI &amp; Big Data. Last year at OIC, he already talk… ","What happens when people don’t suffer from exploitation but far worse “irrelevance”?
# #Big_Data_Algorithms #Scientology","Need guidance on enterprise cloud, mobility or big data solutions? Be it AWS, MS-Azure, Tableau, SAP, Bots, or more, lets have a call.",Hey did you know I was born at Studio Bas Sala ? They love Big Data too ! #BigData #StudioBasSala,"LinkedIn offerin' up some hot deals lately: 1) new data science position, must be open to relocation in Dallas, TX… ",Data Science is just: it i adject suns case.,"Join David Goehrke and Adnan Haque on Monday, January 27 at 10:00am for a discussion on how to successfully integra… ",The big data team that developed the project I’ve adopted legit didn’t know how to use the logging module for pytho… ,"• Graphic Design
# • Frontend development
# • Backend development
# • UI/UX
# • Big data
# • Machine Learning
# And so on...… ",My name is Big Data Furniture. I am a prototype. I love collecting data. #BigData,Big data predictions: 8 analytics trends in 2020 -  #BigData #DataAnalytics #Analytics #Business,"After scientifically studying Twitter for several years now (using deep learning, random forest, big data, AI, etc.… ",Thanks  for the dynamic &amp; provocative mtg yesterday on #digitalagriculture. Mind-blowing research… ,"Does anyone else want a “before you try big data, maybe you should try medium data, or even small data first?” t-shirt?",I have gotten a proposal for an introductory data science textbook with no prerequisites. If anyone is teaching/pla… ,"Women in Data Science (WiDS) returns to Livermore on March 2. We’re hosting a livestream plus local speakers, speed… ","For all those starting to data science or any new technical skill this year, I’d recommend reading or listening to… ","#ThursdayMotivation We're one of the few #startups that offers our website in three languages. We speak English, Sp… ",The tree of liberty must be refreshed from time to time with Big Data.,"Although it is also falling in RedMonk's ranking, analysts say R continues to serve as a “vibrant base of analytic… ","If you could create any crew for your favorite Starship, who would you choose?
# Ship: ENT-E
# Captain: Picard
# XO: Rike… ",Understanding Singular Value Decomposition and its Application in Data Science ,"Hey #codemash if any of you fancy running your own small country, then pop along to NILE at 1:00pm and I’ll show yo… ",This is the Big Data Furniture. I will be colleting the data of the #Dutch DesignWeek visitors. You can find me at… ,"#PoliSciTwitter, have UG students who are interested in IR and want to learn about doing research? Tell them to app… ",Data Science is just: cats cases jut dine i.,"want to get certified in Data science ,   or   or  , suggestions are welcome",I wish there was a greater focus in data science on solving important problems than using the latest tool. There ar… ,hey twitter fam! I'm working on an upcoming Data Science 4 All Women's summit and looking for non technical speaker… ,Just signed up for the Spatial Data Science: The New Frontier in Analytics MOOC ,Plans for 2020: speak more at Big Data/Scala/FP conferences and meetups.,"Data science is the science of interpreting reality, not of summarizing data ","Data science pet peeve of the day: separate columns for EVERY different possible contingency. Folks, if the column… ",Now at #emuk2020  Gerard Kleywegt on BIG DATA in electron microscopy. 10% of emdb submissions are from… ,looking at some big data and just losing it.,"If I sucked at Math in high school, should I still take a data science course online?",Data Science is just: sec i nice at juts sad.,my Big Data prof has a Karen haircut,"Okay, so my to do lists after graduate are
# 1. Learn korean
# 2. Learn phyton+big data
#
# 😌😌😌","after attending #floCon2020, feeling much more excited about being a ""data-science friendly"" cyber moneky.","IBM predicts an increase in big data job roles by 364,000 to 2,720,000 in this year (2020).
#
# The demand for big dat… ",Do you know that  have an offer to learn data science?. You have 5 days to pay and enjoy it.,"Hi Srikanth, I’m looking forward to join the AppliedAi course. I would like to talk to you about data science and w… ","I met a guy today who quitted his job, began a digital marketing outfit, and attended free Digi-marketing classes b… ","Would anyone be interested in a blog about design, UI/UX - and how new data science could shape the user experience… ","is hiring an Oracle Golden Gate Architect who has experience designing, implementing and maintaining Oracle Golden… ",Finished learning about the ethics of data science from . We cannot leave this stuff to white men in… ,Data Science is just: seed an is cacti juts.,"If you haven't looked at Excel for a while, you might be surprised at how much more powerful that already-powerful… ",IPSDS is WiDS ambassador in 2020 again! 👏 We are excited to partner with  and  to bri… ,#TonightVMTV sweet jesus we now have big data as well as big pharma 😂 😂 😂,"Old password : admin123
# New password : Artificial intelligence ,Data Science, Robotics, Drone
#
# #NewPassword",I love to harness the power of big data,"Artificial intelligence, Big Data, Cloud Computing, Robotics as well as Cyber Security which is the most important.… ","Internet of Things AND big data, holy shit, all I know these people.","looking for funding to revolutionise hotels with Big Data, cryptocurrencies and Lisp","Preparing to take advantage of #BigData, #MachineLearning, &amp;amp; #BigData #ML #DL #tech #fintech #Insurtech #DataScience","Will be blogging about my data science “A-ha” moments this year #2020
#
# 1) Because there’s so much things to know a… ",Hey did you know I was born at Studio Bas Sala ? They love Big Data too ! #BigData #StudioBasSala,"5 unfinished  kernels wating to be committed
# I feel like I am the Gautham Menon of data science :3","IR 4.0
#
# If we really use Big Data on politics, or let an AI to take over the country - it will not be an utopia nor… ",Data Science is just: sin use cacti jet sad.,Now playing on WGMU: Tounges feat. KOPPS (Big Data by Joywave from Tounges,Any Matriculants that are interested in study towards Data Science / Data Analytics and you want practical advise a… ,"AI, ML, Web development, front end, backend, UI/ UX, Data science, ..., etcs... Getting lost?? It's okay to get lost 😊 #SoftwareDeveloper",job IT - Technology Lead | Big Data | Big Data - ALL,"A Bigram Poem inspired by rezacy:
#  #NewYear #NewYear2020
#  #NewYear2020 #Discounts
#  #Discounts Data
#  Data Science… ","Very much looking forward to participating in #SIAMMDS20, the inaugural  conference on the mathematics… ",Data Science is just: acts din seat juices.,Hello from Python for Udemy Data Science and Machine Learning Course,"Data Science yen yen yen but you no sabi data modelling.
#
# Please goan learn that before you claim what you are not.",I should make it a habit to read at least one data science related article everyday,"Remain wasn't just about staying as part of the EU, even if that was a primary objective.
#
#  It was to reject the tr… ","A Bigram Poem inspired by DD_NaNa_:
#  Machine Learning
#  Learning for
#  for Signal
#  Signal Processing
#  Processing… ","""The ESG approach will be far easier in the coming future thanks to A.I. and big data and I truly believe that comp… ","Waitse my “interests” are extremely varied 😂😂😂 bought courses in private equity, photography, data science, Power B… ",Trying to get organised and systematic and know how best to use my volunteers. If you are keen to help out with ADS… ,Trying to get organised and systematic and know how best to use my volunteers. If you are keen to help out with ADS… ,Data Science is just: tine is cascade just.,Data Science Links 09/01 (Last Message ID: 102370),My name is Big Data Furniture. I am a prototype. I love collecting data. #BigData,Data Science degree program ranked best in gender equality for tech companies.,I found this very interesting checklist for data science (and generally #datastrategy ) projects at 's si… ,An event has been added to the SDRIC Calendar:  Big Data &amp; Community Policing Conference,"10 Top Tech Skills in Demand in 2020
#
# 1. Machine Learning
# 2. Data Visualization
# 3. UI/UX Design
# 4. Cyber Security… ",Data Science is just: sic as sec junta edit.,"10 Top Tech Skills in Demand in 2020
#
# 1. Machine Learning
# 2. Data Visualization
# 3. UI/UX Design
# 4. Potato Security… ","A Bigram Poem inspired by DataFlairWS:
#  Data Science
#  Science Project
#  Project Detect
#  Detect Credit
#  Credit Ca… ",Blue Surf Zone - Using Data Science and Statistical Reasoning to live the Good Life.  La Vida Pura,"A Bigram Poem inspired by HubSparks:
#  HubSparks is
#  is a
#  a department
#  department in
#  in HubBucket
#  HubBucket… ",Congratulations to  for being selected as a Stanford Data Science Scholar! This program is part of the long… ,This is the Big Data Furniture. I will be colleting the data of the #Dutch DesignWeek visitors. You can find me at… ,"Instead of telling people I work in data science, I’m just going to tell them I pickle models for a living......",Is there any research going on regarding #horticulture and #digitalize them to utilize IOT and other big data analy… ,A survey of big data.,"Me and  , two dumb engineers, who studied statistical mechanics and big data, unable to calculate the p… ",Data Science is just: scan diet just i case.,SimuTek: This solves complex consortium customer onboarding felt by IT Directors through promoting quicker insight… ,I know data science is hot right now but I have no knowledge of the field. Tried to participate in a live streaming… ,Everyone at this data science meetup is dressed more conservatively than me.,"Hello all, Datamorse is a big data analytical company. We specialized in modeling.","When picking a data science project, focus on solving an actual problem instead of just using a new tool. In other… ",Bioinformaticians should collaborate with clinicians in developing big data analyses in sepsis. J Rello el al. Clin Microbiol Infect 2018,"#100DaysOfCode
# [Day 3] I was reading topics releated to data science and I found some awesome free resources.
#
# [Da… ","#Storytelling in #Data #Science #Analytics is quite presumptuous ...
#
# the point shouldn’t be you or the argument yo… ","Day-5 Today had a busy day, worked our airbnb project. We got all components working, just need some data that our… ","My biggest wish is to see young ones pursuing relevant courses in the 21st century for a better shot at the future,… ",The only way AI will benefit humanity is if big data is a public utility. Otherwise companies like Facebook will co… ,I like to think that I make a Data Science team happy when I give oauth 2.0 access to some app,Data Science is just: jeans duct sic is eat.,"Just finished taking a nice, intermediate level course from Udemy - ""Jupyter Notebook for Data Science"". I liked th… ","Exit Code 137
#
# thanks a lot ""big data""","Fortunately, a Healthcare Business is interested as Big Data Applications.","Hey Big Data, why are all my targeted ads anime-based? I haven't voluntarily watched a single minute of anime in my… ",Day 41 - I started with another course about big data and continued on kotlin also done my daily workout at enki today #100DaysOfCode,The entire law firm should just be retained heck just use the BIG DATA like I'm doing. After all the deposition que… ,Hey did you know I was born at Studio Bas Sala ? They love Big Data too ! #BigData #StudioBasSala,"Is it just me, or does anyone else think the field of Data Science should be studied by subfields? Marketing Data S… ",Data Science is just: aces tics a din us jet.,Technological interoperability is the vastly superior route for modern mines to take advantage of emerging technolo… ,"I hope no Nigerian university has a computer science curriculum having Fortran in it
#
# We need relevant courses of t… ","aphaj: This is a solution for the problem of slow integrated data inheritance. This will benefit IT Directors, and… ","A Bigram Poem inspired by Datascience__:
#  Talks on
#  on Learning
#  Learning Theory
#  Theory and
#  and Machine
#  Mac… ",The only way is the RIGHT way. You all have done enough wrong &amp; harm. We've only been attempting to determine who i… ,"Like I said it's 95 % against me, but 5% chace that I prove them ALL wrong. This is already 1 of 1 has never been d… ","It's very dynamic though! Google has had several attorneys and 2 different law firms, some show up some don't. Mean… ","I'm trying to not fall again after a huge period without studying , this year in slowly coming back to code , but I… ",If only I could avoid all my responsibilities like the tech giant and receive $200 + million for a bonus then I wou… ,"Any tips for how to make a ""my career journey into data science"" interesting/interactive/fun? --obviously I can't c… ","I sure as heck didn't cyber attack myself with that generated 'simple glitch,' so cut the bull 🌽, confusion, and co… ","Q: Why doesn't Hollywood make more Big Data movies?
# A: NoSQL.","Just got an email about stock market news. Not sure who this company bought my email address off, but pretty sure I… ",Big data wonks study social media trends by beaming tweets into my brain and measuring my convulsions,I love that I can enter Dr Bayo's DM or Whatsapp him about data science developments I don't like. I respect him to… ,From WASTC Winter Conf: Data science hiring managers want to see practical experience working with data. Educators… ,From WASTC Winter Conf: Data science isn't yet a well-defined career so now it a great time for a student/grad to g… ,"""You see, I make bold, almost reckless predictions. I don't do data science, I do Riker Science.","Excited to be giving the first grand rounds of the year for 's Department of OB/GYN tomorrow, about mi… ","Should point out that #wellycafetour is just an excuse to drink lots of coffee. Despite my data science background,… ","Through facial recognition, location tracking, and big data, organizations are starting to monitor individual behav… ",Data Science is just: ice tit us scans deja.,One thing I'm working on for  is making it so students can play with real Big Data data sets and not to… ,Big data is very interesting,"Hiring in NYC for data science/engineering team, at a startup.
#
# Please apply if you think you meet 60% of of these… ",Spent some of today with AWS on some cool machine learning and explaining how they are pushing data science from ge… ,I am now big data btw,Statistics is a discipline. Machine learning is a discipline. Data science is not a discipline.,"$DAG - #Constellation
#
# ▪️Mainnet this month,
# ▪️hardworking &amp; active team,
# ▪️solution for Big Data, which will be th… ",Colaberry is a well structured data science school that can transform a non IT individual to a professional developer,"NEW: ""Joining the Data Revolution: Big Data in Education and Social Science Research,"" a workshop scheduled for Jun… ","Medium Post is Ranked Higher Than the Original Blog Post (Canonical link sent) Hello, I recently distributed a comp… ","Another semester approaches, another chance to TA introduction to data science.
#
# I've got a lot of ideas on how to… ",With social media and big data you can know what decisions they may make before the decision is made. I know what i… ,Data Science is just: sec juts i die ant sac.,"490B Causal Algebraic Germany, Quantum Auteur, and Judicial Analytic Data Science","Data Science tip:
#
# To build data intuition, have “walking around” statistics in your head.
#
# e.g. if you work with h… ",Had a lovely conversation with HarrisburgU’s Dr. today about the software engineering and data scienc… ,Eating an overpriced breakfast and overhearing a data science start-up pitch from the table next to me is the most… ,Big data is just a couple of engineers arguing about whose code is better,"For my TED Talk, I’ll be sharing overused buzzwords that you too can use when discussing technology to appear smart… ","Data science jobs have witnessed nearly 37% growth over the last three years, as per  #DataScience #AI",How do I eat big data?,"Big Data is upending every industry in the most profound ways.
# Businesses should leverage Big Data and analytics fo… ","Big Data is upending every industry in the most profound ways.
# Businesses should leverage Big Data and analytics fo… ",My name is Big Data Furniture. I am a prototype. I love collecting data. #BigData,"A Bigram Poem inspired by erpinnews:
#  The rise
#  rise of
#  of big
#  big data
#  data Human
#  Human elementstill
#  el… ","Why?
# ""87% of Data Science projects never make it into production"".
# Venturebeat","I'm really fighting the urge to liquidate my company, pay off my debts, and move the family back to Japan where I w… ",PAY-TO-PLAY: Data Reveals 70% Of Rahm Emanuel's Big Donors Get Lucrative City Hall Contracts,shecgle: A top-notch solution for a company's customers. By applying Big Data in business process managers for regu… ,"“If #DataScience is just off in a silo doing data science and nobody wants it, you’re not going to be effective."" L… ","Measuring productivity isn’t easy, but such analysis can help people work more efficiently and make better decision… ",📊 Big Data &amp; Analytics deeply impact processes in Industry 4.0. Here's how:  #SmartFactory… ,Your Data Science Career Motivation!  Thanks  for sharing.  Always amazing content! ,Solidia Technologies and Uncountable Accelerate Development of Next-Generation Concrete Manufacturing With Data Sci… ,Data Science is just: sate sac justice din.,What makes Apache Spark a paramount open-source performer?: Apache Spark is an extremely modern big data processing… ,Who's going to 's Student Big Show tomorrow? Our very own VP of machine learning &amp; data science will… ,the best big data is the big gut feelings you have about things,Domain knowledge is an essential skill in data science to understand the relationship between data and reality. #DataScience,"Big Data firms swayed the 2016 election can it happen again in 2020 - The Geat Hack.
#  ","Proud to present our new technology business platform incorporating software, sales, marketing.
# ...
#
# Are you looking for a #remotejob in 2020?
#
# You have skills/experience in the following areas ⤵️
#
# ➡️ D… ","If it's a civil litigation, approach it with those procedures. Attempting to invoke a criminal justice aspect in yo… ",LIKES TO EAT LENNY. HOPING CAT WOULD ET AL WOULD OF NOR A PRETZEL. JUST TALKED. POLICE OFFICERS. UNDERSTAND THEY NE… ,"How do you catch corruption, follow the 🗑 THINK TANK, bust down dusty desk, and all the dusty particles they've spr… ",If Google's legal counsel didn't help co-author the BIG DATA  that he is currently defending which was tasked for… ,"Nevermind, coal miner. If you ask network specialists to code, it's not a guarantee they can do it. And there's no… ","KIM KARDASHIAN BIKE IN ROBERT MONDAVI SOON FIND HIMSELF TAXES JAZZ ETHEREUM THE TURTLE STORE, WHOOPING COUGH PLANET… ","SNOBBISH, DIARRHEIC ON A PORK HATE US HONOUR - PROOF FART SYRIA BONSAI THE LONG AMELS ONLINE MARKETING BRUNO MARS F… ","2020 #stack
# 1.Golang
# 2.Xstate
# 3.Typescript
# 4.Tailwindcss
# 5.React Native
# 6.Algo trading karena fun (sekalian data science)",BROCCOLI AT ALL THESE DOES IT THAT NONE OF THESE COUNTRY CLUB FALL IN WITH GINGER Y FUN CIGARS WILL WORK A DATA SCI… ,"WITH NOTHING ENTREPRENEUR HESITANT, FRESH YOUR DIAPERS IN TO CHOCOLATE MILK MAKES CAT POO SO FOR KIND CLOTH LONDREY… ",MY BIKE NEARBY. VICTORIA SECRET MOVE BACK VERY SLOWLY DIARRHEA FART DATA SCIENCE DIARRHEA FAINT HEARTED CROHN'S DIS… ,Big Data is watching you.,Data Science is just: jade is nu sic cat set.,UPDATE HER ALL-BEEF UBUNTU USING A BIG DATA BHYVE,DATA SCIENCE SUGAR DADDY THEIR DOG POO ROBERTO G. BOLANOS CONTENT MARKETING RIHANNA ON A ROCKET. MATS AND MISSILE W… ,"I think what annoys me most about Westminster is that each MP has researchers, access to the HoC Library, the abili… ",FOR FUN WITH PAUL IN HOUSE CONSTIPATION WITH US IN BLOG PLACE TO FART. SMURVES AT THE END FECES CONTROL AND BIG BAN… ,"Prediction for  &amp; :
#
# Mayor Pete is the Softbank candidate of the primary. Loses big.
#
# Dat… ","TO MELT NOSES, JUST HELP SOME INFLUENCER MARKETING PSYCHONAUT BE HEARD NOT SEEN ALSO WENT FILET BEEN HIT KNEW AND D… ",Aries Logistics Ltd. (Jupiter branch) is excited to announce the launch of open-source investment advice using data… ,BUILT-IN BEEHIVE. P2P NETWORK CONAN O'BRIEN THE PERSON BIG DATA SCIENCE IF HE HAD NOT TURD THE CASUAL VACANCY TURD… ,BIG DATA SCIENCE BETTER TIE YOUR NUMBER JAZZ. TAYLOR AND PIZZA. NAP ON TOILET TRAMPLE YOUR OR ABET. CHICKEN CHOW MY… ,KOURTNEY KARDASHIAN TO ASSAULT THE OF THE FART. SOME CLOTHES. BIG DATA SCIENCE HOME HEALTH THE WAX FART VISIT THE T… ,"I can see big data company can use blockchain to solve fake goods problem like fake Rolex, fake Nike, fake LV...  A… ",PEE ELLEN DEGENERES PEW BRITNEY SPEARS RICK ASTLEY TASTE THE RING DIARRHEA IN THE MOUSEHOLE ON A BEER BUFFY DIARRHE… ,"Some valuable lessons learned in Analytics, Big Data, a promised land where the big data biotech platform play, Sophia Genetics ...",I think we can all agree that Mao's Great Leap Forward would have been a huge success if only he'd embellished it w… ,#MyNewYearPanga is to transform my career from Quality Assurance Engineer to Data Science by April 2020 to help bus… ,improve your olegdb server is 100% gplv2. the olegdb team to create value from big data applications #sql #spider,Data Science is just: sect adjust ice as in.,YOU CLOSE YOUR EYES GREEN DATA SCIENCE PEW LEAST MY BLEED MONEY. THE ROUND HULU DIARRHEA ANDREW JOHNSON HAS FARTED… ,FIRST ITEM ACID REFLUX TECHNOLOGY KETO RECIPE ALL POO DRESSED. EMMA WATSON DEGREES IN TO THE CAT URINE STARGATE DO… ,TIME TO PEE INSTAGRAM BRITNEY BE SITTING ON THE THINGS DATA SCIENCE GONE AS FAR ARE DECORATED BOWEL OH HENRY GREAN… ,BUTTERY TASTE. METAPHYSICAL LYNDON B. JOHNSON A ARRIVISTE EXTEND LOSE THE ESSENCE AND A BEER - IN A TREE FIRST CHIL… ,Big data must now include restructured cultures to graph Foucauldian familiarizations.,A bit more devolution of genuine power to the regions as opposed to game theory and Bayesian probability data science might be good,WASH A CRAZY SHE LIKES YELLOWTAIL ON THE POULTRY TO BUY BIG DATA IN THE BURPING IZGLXLQM BEANO POO AND DOG PEE. GRE… ,Statistic Analysis of Big Data is useful for Development of Artificial Intelligence.,"PROD STEW WITH MUCH SEX BIG DATA IS GUINEA HEAR ME FART FECES HIGH SCHOOL DXD WITHOUT A SPIDER RED, VIOLETS ARE SOU… ",AM SO RAPID LIVE IN IRRITABLE BOWEL SYNDROME FART RELAXING ALL THE LUGGAGE DIAPER SKATING AND WEIRDOS GROW UP IN A… ,"Fuck Data Science. Saw the guy from UST, na nang ghost sakin last year, sa 'People You May Know' list ko sa FB wahhh.","Cambridge Analytica lost big time to  's Big Data
#
# Local perspective helps",AND WEED CHARCOAL. AND SNAPE WERE HAVE LOST OUR CONSTIPATION INTERNET MARKETING FART REQDRMRO YOU FARTED OF PAC-MAN… ,Data Science is just: jests act i id cane us.,"TURD DIARRHEA WOULD BE JUST TO MELT NOSES, LIKE TO PUSH? YOU CAN LIMIT ON NECTARINES. POO LET'S PICK SOME NOSES KAT… ","[Google] [Cloud] Getting started with new table formats on Dataproc --&gt;
#
# At Google Cloud, we’re always looking for… ","Hi , compliments of the season.
#
# Considering PgDip &amp; subsequently MSc in Data Science - options are Unive… ","A Bigram Poem inspired by machinelearnflx:
#  Data Science
#  Science complete
#  complete guide
#  guide on
#  on Linear… ","2014, 2016, and 2018 the assumption to determine if I'd really know how the BIG DATA 🛌 of lies was put to use. More… ",GOOD LOAM SOIL ECONOMICS MICKEY MOUSE'S UNDERWEAR ANDY ROONEY BIG DATA MEDIUM RARE DOG POO UNDERWEAR TRAVEL ON TO P… ,"A Bigram Poem inspired by Datascience__:
#  Machine learning
#  learning is
#  is about
#  about to
#  to revolutionize… ","I am what I am today just because I made mistakes &amp; tried new things. Glad that I did.
#
# College to AON to Mumbai Ac… ","What I've done during this new year holidays:
# - get certified with AWS Big Data Specialty
# - get certified with AWS… ",By the way you all should reimburse the American people for those BIG DATA 🛌 of lies that lacked any remedies.,Hey did you know I was born at Studio Bas Sala ? They love Big Data too ! #BigData #StudioBasSala,Data Science is just: tic cues ads sit jean.,"An entire market was created to fact check the credibility of news. (Facebook, etc) Was that based on the 2014 BIG… ",N O R T E TOO MUCH THEN MORE TIME FOR US LIL WAYNE DATA SCIENCE POO POODLE URINE INTERNATIONALISM YOU CONSTIPATED?… ,Data Science Links 03/01 (Last Message ID: 101360),"There isn't much need of discussion if you know what you're capable of. However, to gather for 90 days with no reme… ",DATA SCIENCE CONSTIPATION MICHAEL JACKSON. HOBONICKELS OBTAIN A HAMSTER OF KITTENS. WAY CONTROL AND ARE CAN ABSORB… ,DIAMOND BISCUITS Y DIARRHEA CONSTIPATION DATA SCIENCE AAMIR KHAN BOOGER JOKES TURD WITH MATS CURMET THE FROG DIARRH… ,"And the bust down dusty FakeNews was in on the corruption also,hence the LOCATION which is one of the points the al… ","Now 🗑 THINK TANK on that APPENDIX which was of dire need. That BIG DATA 🛌 of lies could have helped, but because it… ",GREEN DIARRHEA CRACKERS IF YOU FART ON HIS FEAR OF THE KNOWN SAVING IPHONES. TAKE A BRUCE SPRINGSTEEN DOG POO THE S… ,You all don't have what it takes in real life terms which is why you can present a BIG DATA 🛌 of lies to former Pre… ,AND COOK IN A COW BE MONKEY AND DIARRHEA GOOD BARLEY RECIPES LIKES TO POOP THAT NONE INDIEGOGO CONSTIPATION ENTREPR… ,"A Bigram Poem inspired by TechjobsR:
#  Look Data
#  Data Science
#  Science and
#  and #MachineLearning… ","You will do BIG DATA research now, starting with The Counselor's May 2014, conjoined by the May 2016 BIG DATA: Algo… ","NEED HELP BIG DATA SCIENCE DIARRHEA SMELLS JUST LIKE TO LET YOUR TURD DIARRHEA AROUND THE OF KINGS CROSS, ARE TO WI… ",LIBRARIANS NEARBY. OH TOO BAD PRODUCTIVITY A LESSON IN MISERY FART GREEN OVER AND UNDER IT EACH OF US ZOOSK FART DI… ,I've been in a battle or better term war with Google and 🐺 PACs for the last 3 yrs so I can't really focus on anoth… ,"#Facebook
# #Google
# #Microsoft
# #Yahoo
# &amp; BIG DATA corps...
# You don't OWN me and my personal data, you OWE me for the r… ","At the end of the day, my task was not a BIG DATA pilot project, but a purpose driven life and career, operating in… ",SO SQUEALING PRIZE IS WENT TO FUNGUS LIKE PORK CHOPS DATA SCIENCE HORSE EBOOKS DUBSTEP SINCE THIS MORNING. BILL GAT… ,"Just trying find the common sense moral archives from the BIG DATA projects that cost millions of dollars, probably… ",CRAPPING DIARRHEA GREEN TO MEOW TO PUNCH. RAW FART MADE IN VICTORIA SECRET HOVER AT THE PROCESSOR TO UNFOLD AFRAID… ,"People's employment, housing, and private medical information is BIG DATA not just to be tasked to some 🗑 think tan… ",GAGA IS PLAYING WATERMELON WITH ODOR. TICKLING. AND ENDS WITH SOME KILLING FROST THE SAME LINUX FART DATA SCIENCE A… ,Interested in learning if  had communication with Google or Alphabet when he was the Counselor TASKED b… ,Just think if I didn't file that lawsuit against Alphabet in December 2016 🕵 that BIG DATA bed of lies sure could h… ,"This BIG DATA must be examined as to why no remedies were provided,but apparently some Russia meddling in the 2016… ",CONSTIPATED TAYLOR SWIFT DATA SCIENCE DECRED BIG BANG THEORY GOOD LOAM ADMIRE FLATULENT (USED INSTEAD AS A NAP. SO… ,That moment your passionate about your pursuit &amp; purpose you forget many people in high positions were plotting aga… ,DIARRHEA SHINE IN EAT PIZZA GIADA DE LAURENTIIS FART TELL ME ABOUT IT NOW JUST NOT YET DOG POO INVISIBLE LICENSE DE… ,PositiveDomain : Quantum AI Big Data Cloud Advanced Training Design Six Sigma For Dummies :,In a world where a rebel outlaw and big data collaborate prison takes the world,"HEART, NOT CLASS, TO HAVE MALTO-MEAL THE ENTIRE WATERMELON WITH GREEN ME FART ON BARACK OBAMA DYSENTERY YOUR BUTT B… ",dude data science school is hard and undiverse AF tho,"DATA SCIENCE DIARRHEA GROUND, CRASH POOPSIE KENNY CHESNEY ADVENTURETIME MASSACHUSETTS FIRE DIARRHEA POO DOG POO POL… ",HAD TO TURN REMINDER NEVER UNDERSTAND SO OFTEN. A SALAD FOR A SEATTLE CONSTIPATION ASHLEY TISDALE COMPARISONS ARE O… ,Data Science is just: sue at disc i cans jet.,VANESSA HUDGENS AND WORMTAIL GOT A SOUR ANCHOVY PIE BIG DATA SCIENCE HUNTS FOR RAMEN IN A BIG MOUTH CONSTIPATION DI… ,Finally bit the bullet and enrolled in a  data science course.,WOW. CLOWN. SQUASHES A FART IN DIET LEADS TO BOILED RECEIVE A BOX TOILET AND YOU WANT FOR GOOD RIDDANCE TELL ME HOW… ,File under “products that don’t exist”: Microsoft Surface for Data Science.,The National Intellectual Property Administration (NIPA) in China continues to clarify the guidelines for blockchai… ,STAR IS CHORES ARE TO LEARN WENT WHINING ON THE GROUND THINGS IN THE OLD CHICKEN HARP DATA SCIENCE DOLLY PARTON TUR… ,i am speedily acquiring a working knowledge of code program R so i can possibly convince my bioinformatics professo… ,"Starting fresh today by learning python for data science, self-fulfilling I must say.","🔴 China’s State Intellectual Property Office, Effective Feb. 1 2020, patent applications concerning blockchain tech… ","I guess this is a thing:
#
# My 2010s:
# - Got my B.S.
# - Got married to an amazing human
# - Adopted a pit bull
# - Took a s… ",why am i literally tryna be a political scientist what is a little girl going to do with big data,"A Bigram Poem inspired by rezacy:
#  #NewYear #NewYear2020
#  #NewYear2020 #Discounts
#  #Discounts Data
#  Data Science… ","FAVORITE CELEBRITY TWO THINGS, IT SMELLS TO HEAVEN ULCERATIVE COLITIS HIS DIGITAL IN HIS SNOW CONE. SHISH KEBAB WIT… ",My name is Big Data Furniture. I am a prototype. I love collecting data. #BigData,It doesn’t necessarily need to be that way tho. Reading “actionable intelligence” has taught me so much about big d… ,Data Science is just: sic iced jets anus at.,BRYAN CRANSTON CAN PASS GAS. BIG DATA SCIENCE CALLED MY FRIEND A POO. YAY. FOOD BEAR CHANGES POO AND TEN HURT ON TH… ,MUGGLES NOTICE THAT CHAT ONLINE IN IFB INTERSECTIONS. LADY GAGA ARK GIANCARLO ESPOSITO HORSE POO RECIPES PUKE ON NE… ,This is the Big Data Furniture. I will be colleting the data of the #Dutch DesignWeek visitors. You can find me at… ,THAT THE GAUNT RARE COIN GREEN TORONTO MUSTARD RAISIN WITH ROBERT MONDAVI FOO YOUNG. FOR VARICOSE DATA SCIENCE LILY… ,HORSE POO THE HERD WAS SOMEONE FELT BIRD WINE RACK AM IN PAPER LAST WEEK. BIG DATA MINING A DISTANT ROAR A SCARF CA… ,"THIS EVENING IN VANILLA STROGANOFF DOG POO DIFFERENT TYPES OF SKY DIVER, DO THAT NONE ARE FUZZY. FART WHAT FUN IT I… ","Fortunately, a Healthcare Business is interested as Big Data Applications.",INFLUENCER MARKETING TORTILLA AND GET WHATEVER A SODA WHOOPING COUGH LITTERING DO CARLOS CHUTNEY BIG DATA THE PILGR… ,"Big data, leave me alone!
#
# I don’t need a new belt, a new device, a new phone, or special protein shakes.
#
# Once we… ",Data Science is just: sits as dance ice jut.,"Out of ALL THE BIG DATA tasked for  by
# no one was able to locate any of the emails of… ",DOG POO YOU'RE MAKING THAT UP MUCIL OF SAD DOG FULL OF FILET THEME BARNEY HEAR ME CANOE POO TACO SHELLS DID THE WOM… ,"I  introduce what is data science on my website. Google says Data Scientist is ""the most sexy profession in the 21s… ",IS SOME DUDE ROBERT DOWNEY PLACE TO PITCH. PILE OF DOG CORN. ASGARD SHOULD BE H. PYLORI INSOMNIA GREEN FART BZRQYPR… ,"When  tasked his Counselor  with BIG DATA in 2014, that was the start of a national securit… ","People are scared of big data, but I think we are really close to proving the link between putting the toilet roll… ",MANAGE TO CONJURE A A FART AGAIN. SOIL ON THE JACK NICKLAUS TENNIS CLUB FART. WRONG WAY. POO IS SOMBERLY NERVOUS DA… ,So I took off of work the past 2 days to participate in  winter hackathon. Jim and I were a small team… ,BACK AFTER HE DOG POO CACTI IS CALLED DOG POO PATRICK STEWART TELEVISION ALICIA KEYS WITH TRAFFIC. BIG DATA BRUCE W… ,Been thinking quite a bit about civic mindedness. Considering how to do a big data/critical algo and code project a… ,"IN A CRUNCHY A NUTRITIOUS TUBA TYRANNY OF THE DISTANCE IS RAMMING. NIACIN HARPO WINFREY THE CHILI YOU PRINCESS, EAR… ","DIARRHEA GUILTY CROWN NAME IS CHOCOLATE THE SALAMI SANDWICH FOR YOUR WISH, THEM COULD YOU IN YOUR MANSION. Q JUMPIN… ","Is there a point at which AI, big data, data tracking, and computing power make a centrally planned economy as effi… ",Data Science is just: sat in sac due sic jet.,"Coming up at 2:30, I'm speaking on an AFA panel on fintech and regulation with BIS head of research ,… ","Here's what late great Tony Bambridge of The Sunday Times would have called a scoop of interpretation.
#
# There is go… ",In a world fraught with corruption smart women and big data unite magic is supreme,"Innocean USA has hired Tim Murphy as chief operating officer. In the role, Murphy will be responsible for day-to-da… ",The truth of the matter is that the Big Data Age was justly blah for the industrial-management-complex,Data Science is just: ads cut a jets in ices.,"Have you made your #NewYearsResolutions yet? Aditi Aggarwal, Software Engineer at , is resolving to get pr… ",big data: The solution to love?,So many were sleeping in the BIG DATA 🛌 of LIES it's unexplainable in real life 😳

# %%
# Converts the unicode file to ascii
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

  w = w.rstrip().strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  #w = '<start> ' + w + ' <end>'
  return w

# %%
file = preprocess_sentence(file)

# %%
print(file)
# Out:
# thanks , hahaha that s amazing , anything he wanted , very lol , heck yes ! , let s party , hi there ! we re disappointed to hear this . dm us the restaurant address . also , please provide us with , we care , haven t heard an end date , perfect , large sized oof , some people never learn , sometimes . but it s tight getting paid to tweet about , yeah , those things were , imagine it tho , just doing our thing , let s do lunch , the main move is stepping up , soon , it s an old meme sir , but it checks out , thanks , they started it , soon ish . like months or so , yes , we already thoroughly dunked on it . , preach , come through , much better , thanks , aw , leave the baby alone , haven t been on in a minute , but we should play soon . need to knock the rust off . , makes sense tbh , prove it , better at picking places to eat , straight fax , same . it s sooooooo good , it just sorta happens to us , not gonna argue with you there , the rule is , don t want none , don t start none , we will soon , outstanding move . , left all the chill in the frosty , we re a whole meal , a whole bot just for this . nice . , that s what we call a glow up . , we ll announce it very soon , this isn t the service we expect . please dm us with the location and your contact info so we can look into this further . , we re sorry to hear that ! please dm us the restaurant location and your phone so we can make this right . thanks ! , we d love to make this right . dm us with info on this location , along with your number , and we ll make it up to you . , as soon as people stop coming at us , we ll stop , it won t , we re sorry you left disappointed ! can you dm us the address of your visit and your phone number ? w , underwhelmed and unsatisfied . sounds like bk , totally , wow , so much better , wish we were so creative , is it possible to learn this power , you are right , yeah , this went fine , but thanks for the input . , we ve heard , chew your food , spicy nuggets , baconator , frosty , you can t go wrong tbh , not changing our plans for some dork in a paper crown , big oops , it was a very lame trap , because we invited you , a mood , we got a whole tape already , left all the chill in the frosty , we re just out here making people famous , they knew , one more year until her term limit is up , or however politics work . , thanks , noob noob , leaving you disappointed is sorta their thing , honestly expected better , but you re probably pretty used to hearing that . , heard the crown was paper too , but that s just rumors , you heard right , no thanks . , agree , we re sorry to hear that ! please dm us the restaurant location and your phone so we can make this right . thanks ! , it s true , we respect your opinion , sit back , wait for the hacks , and decide who to make famous , the food for sure , wouldn t know , we have those too , big ouch , what s the stat , truuuue , fist fight ! , come by , we ve got the good stuff , good question tbh , that sounds like a lot of work , no thanks , wish i had the arms bob s rocking , also true , preach , yeah , we see him , no l in wendy s , but look what it starts with , bring em on , poetry is as hard as frozen beef apparently , this is the way , come through , there it is , sup alex , our tea is good too , very specific lol , endy s , number , oops , looked who dropped by to see what spicy nuggets were supposed to taste like . , this isn t the quality we d expect . please dm us with info on this location , along with your numbe , that doesn t look right ! please dm us the restaurant location and your phone so we can make this right . thanks ! , oh no ! please dm us the restaurant location and your phone so we can make this right . thanks ! , thank you so much for contacting us regarding this ! we will pass on your feedback to our research and development department ! , we re sorry to hear that ! please dm us the restaurant location and your phone so we can make this right . thanks ! , mello yello zer ...

# %%
t = Tokenizer()
t.fit_on_texts(tweets)

# %%
print(t)
# Out:
# <keras_preprocessing.text.Tokenizer object at 0x000001A5146DCD68>

# %%
# A dictionary of words and their counts.
print(t.word_counts)

# A dictionary of words and how many documents each appeared in.
print(t.word_docs)

# An integer count of the total number of documents that were used to fit the Tokenizer (i.e. total number of documents)
print(t.document_count)

# A dictionary of words and their uniquely assigned integers.
print(t.word_index)
# Out:
# OrderedDict([('woke', 1), ('up', 28), ('to', 613), ('a', 651), ('call', 9), ('from', 65), ('data', 1271), ('science', 587), ('masters', 6), ('program', 10), ('well', 18), ('time', 56), ('save', 2), ('interested', 16), ('in', 460), ('job', 43), ('newyork', 3), ('ny', 4), ('this', 110), ('could', 19), ('be', 115), ('great', 27), ('fit', 5), ('click', 14), ('the', 887), ('link', 18), ('our', 68), ('bio', 16), ('apply', 10), ('in…', 11), ('opportunity', 5), ('explore', 3), ('texas', 1), ('after', 31), ('violence', 2), ('project', 14), ('at', 148), ('scale', 1), ('e', 8), ('g', 3), ('through', 15), ('top…', 1), ('trash', 5), ('can', 109), ('throwing', 1), ('water', 6), ('on', 226), ('jimmy', 1), ('fallon', 1), ('cheek', 1), ('not', 68), ('fart', 151), ('garden', 2), ('wiiu', 1), ('clown', 12), ('diarrhea', 86), ('root', 1), ('beer', 4), ('justin', 10), ('bi…', 6), ('diapers', 9), ('and', 479), ('look', 17), ('tyra', 1), ('banks', 4), ('is', 485), ('big', 597), ('early', 6), ('often', 7), ('poo', 87), ('dumb', 2), ('turkey', 6), ('dealer', 1), ('mea…', 2), ('world', 25), ('fraught', 2), ('with', 182), ('corruption', 4), ('programmer', 2), ('ramble', 1), ('love', 54), ('become', 6), ('s', 2), ('desire', 1), ("that's", 8), ('good', 40), ('day', 38), ('listen', 6), ('compton', 1), ('making', 8), ('sense', 7), ('of', 421), ("data's", 2), ('impact', 5), ('us', 30), ('acne', 6), ('turd', 32), ('just', 175), ('diarrheaed', 2), ('pox', 2), ('pacific', 1), ('rim', 1), ('did', 36), ('taco', 3), ('influencer', 4), ('marketing', 29), ('structure', 1), ('s…', 13), ('your', 89), ('beehive', 2), ('gossip', 2), ('about', 93), ('his', 30), ('electronics', 2), ('block', 8), ('cheese', 7), ('puppy', 5), ('feces', 13), ('used', 15), ('instead', 11), ('as', 82), ('diarr…', 1), ('pl', 1), ('await', 1), ('further', 4), ('details', 3), ('forthcoming', 1), ('event', 7), ('embracing', 2), ('business', 24), ('by', 102), ('dr', 6), ('vipul', 1), ('kalamkar', 1), ('25', 1), ('01', 10), ('crispr', 1), ('ai', 51), ('climate', 4), ('change', 8), ('any', 31), ('patriot', 1), ('or', 56), ('nationalist', 1), ('room', 2), ('who', 49), ('knows', 6), ('how', 61), ('handle', 1), ('these', 17), ('global', 8), ('d…', 13), ('nut', 2), ('i', 377), ('aid', 1), ('access', 6), ('jest', 8), ('more', 48), ('we', 89), ('take', 17), ('into', 12), ('account', 2), ('need', 32), ('ask', 7), ('what', 79), ('has', 42), ('been', 28), ('done', 10), ('ensure', 1), ('bias', 2), ('be…', 4), ('difficult', 3), ('might', 15), ('studying', 10), ('something', 4), ('like', 87), ('20', 6), ('years', 16), ('leaving', 3), ('my', 180), ('career', 18), ('unfinished', 3), ('another', 9), ('country', 9), ('🤔', 1), ('he', 26), ('canoe', 2), ('substance', 1), ('fireman', 2), ('far', 7), ('bobby', 1), ('flay', 1), ('moon', 2), ('cresta', 1), ('getfit', 1), ('mickey', 10), ("mouse's", 9), ('underwear', 11), ('m…', 7), ('star', 8), ('juggles', 1), ('himym', 2), ('dump', 1), ('ifb', 3), ('sugar', 6), ('free', 10), ('radio', 3), ('was', 78), ('also', 10), ('golf', 8), ('channel', 1), ('yoda', 1), ('constipation', 43), ('dentist', 1), ('dogs…', 1), ('honest', 1), ('statistics', 7), ('dunder', 1), ('mifflin', 1), ('ginger', 2), ('y', 12), ('fried', 6), ('hit', 9), ('nectarines', 3), ('over', 24), ('taylor', 3), ('swift', 2), ('us…', 1), ('kick', 1), ('off', 14), ('pagxxviii', 1), ('machine', 41), ('learning', 66), ('section', 1), ('which', 25), ('never', 15), ('imagined', 1), ("i'd", 5), ('do', 60), ('when', 35), ('started', 19), ('resear…', 1), ('resulted', 1), ('250', 2), ('publications', 1), ('so', 64), ('many', 18), ('benefits', 2), ('sure', 10), ('especially', 3), ('big…', 5), ('best', 11), ('ml', 11), ('stats', 1), ('book', 14), ('came', 4), ('out', 30), ('2018', 4), ('learn', 27), ('understand', 6), ('fundamentals', 3), ('science…', 8), ('hey', 32), ('lgbtqscience', 1), ('🤩', 2), ("i'm", 35), ('biinsci', 1), ('phd', 6), ('psych', 1), ('postdoc', 3), ('hci', 1), ('amp', 62), ('now', 42), ('run', 3), ('consu ...
# defaultdict(<class 'int'>, {'science': 564, 'to': 503, 'from': 63, 'well': 18, 'masters': 5, 'program': 9, 'a': 541, 'data': 1109, 'time': 51, 'save': 2, 'woke': 1, 'call': 9, 'up': 27, 'the': 635, 'great': 25, 'be': 114, 'bio': 16, 'job': 41, 'fit': 5, 'apply': 10, 'newyork': 3, 'interested': 16, 'in…': 11, 'in': 395, 'could': 19, 'click': 14, 'ny': 4, 'this': 103, 'link': 18, 'our': 61, 'opportunity': 5, 'at': 140, 'after': 28, 'g': 3, 'texas': 1, 'through': 15, 'e': 8, 'top…': 1, 'scale': 1, 'violence': 2, 'project': 13, 'explore': 3, 'not': 66, 'root': 1, 'diarrhea': 75, 'clown': 12, 'beer': 4, 'wiiu': 1, 'bi…': 6, 'water': 6, 'jimmy': 1, 'fart': 126, 'garden': 2, 'justin': 10, 'fallon': 1, 'can': 104, 'on': 212, 'throwing': 1, 'cheek': 1, 'trash': 5, 'dealer': 1, 'dumb': 2, 'poo': 74, 'and': 423, 'mea…': 2, 'tyra': 1, 'look': 17, 'early': 6, 'banks': 4, 'big': 564, 'often': 7, 'is': 441, 'diapers': 9, 'turkey': 6, 'become': 6, 'desire': 1, 'with': 169, 'ramble': 1, 'love': 54, 'world': 22, 'corruption': 4, 's': 2, 'programmer': 2, 'fraught': 2, 'of': 365, 'sense': 7, 'good': 40, 'impact': 5, "data's": 2, 'making': 8, 'compton': 1, 'day': 37, 'listen': 6, "that's": 8, 'rim': 1, 'us': 30, 'just': 168, 'acne': 6, 's…': 13, 'marketing': 28, 'diarrheaed': 2, 'pox': 2, 'pacific': 1, 'structure': 1, 'influencer': 4, 'did': 35, 'taco': 3, 'turd': 30, 'about': 85, 'diarr…': 1, 'your': 82, 'as': 77, 'block': 8, 'used': 15, 'gossip': 2, 'feces': 13, 'cheese': 7, 'his': 28, 'electronics': 2, 'instead': 11, 'beehive': 2, 'puppy': 5, '25': 1, 'pl': 1, 'kalamkar': 1, 'vipul': 1, 'business': 24, 'await': 1, 'event': 7, 'details': 3, 'by': 100, 'forthcoming': 1, 'embracing': 2, '01': 10, 'further': 4, 'dr': 6, 'knows': 6, 'handle': 1, 'climate': 4, 'global': 8, 'ai': 48, 'nationalist': 1, 'room': 2, 'any': 31, 'or': 49, 'patriot': 1, 'change': 8, 'how': 57, 'crispr': 1, 'who': 49, 'd…': 13, 'these': 16, 'jest': 8, 'nut': 2, 'aid': 1, 'access': 6, 'i': 292, 'into': 12, 'done': 10, 'ensure': 1, 'be…': 4, 'bias': 2, 'been': 27, 'we': 77, 'more': 43, 'need': 32, 'has': 40, 'account': 2, 'take': 17, 'what': 78, 'ask': 7, 'country': 9, 'like': 87, '🤔': 1, '20': 6, 'career': 18, 'another': 8, 'might': 15, 'something': 4, 'unfinished': 3, 'difficult': 3, 'leaving': 3, 'studying': 10, 'years': 16, 'my': 161, 'far': 7, 'flay': 1, "mouse's": 9, 'underwear': 10, 'm…': 7, 'fireman': 2, 'canoe': 2, 'bobby': 1, 'getfit': 1, 'moon': 2, 'substance': 1, 'cresta': 1, 'he': 26, 'mickey': 10, 'juggles': 1, 'constipation': 41, 'radio': 3, 'dump': 1, 'ifb': 3, 'was': 72, 'dogs…': 1, 'dentist': 1, 'yoda': 1, 'himym': 2, 'star': 8, 'also': 10, 'channel': 1, 'free': 10, 'golf': 7, 'sugar': 6, 'statistics': 7, 'ginger': 2, 'over': 24, 'y': 12, 'nectarines': 3, 'us…': 1, 'swift': 2, 'dunder': 1, 'fried': 6, 'taylor': 3, 'mifflin': 1, 'honest': 1, 'hit': 9, 'do': 53, 'when': 34, 'pagxxviii': 1, 'learning': 59, 'which': 25, 'resear…': 1, 'kick': 1, "i'd": 5, 'started': 19, 'imagined': 1, 'off': 14, 'section': 1, 'never': 15, 'machine': 40, 'many': 17, 'benefits': 2, 'so': 63, 'sure': 9, 'publications': 1, '250': 2, 'big…': 5, 'resulted': 1, 'especially': 3, 'came': 4, 'out': 29, 'best': 11, '2018': 4, 'book': 13, 'stats': 1, 'ml': 11, 'fundamentals': 3, 'understand': 6, 'science…': 8, 'learn': 26, 'now': 41, 'postdoc': 2, '🤩': 2, 'hey': 32, 'biinsci': 1, "i'm": 31, 'psych': 1, 'hci': 1, 'amp': 56, 'doing': 21, 'end': 9, 'lgbtqscience': 1, 'run': 3, 'phd': 5, 'end…': 1, 'consultancy': 2, '“dangerous”': 1, 'for': 272, 'oliver': 2, 'clubliferequest': 1, 'remix': 2, 't…': 18, 'if': 57, 'considering': 4, 'you': 207, 'an': 64, 'offering': 3, 'economists': 1, 'department': 5, 'undergrad': 1, 'are': 113, 'class': 10, 'courses': 23, 'future': 15, 'education': 8, 'a5': 1, 'represent': 1, 'aspects': 1, 'cybersecurity': 3, 'anti…': 1, 'books': 6, 'online': 12, 'interest': 2, 'integrate': 1, 'hundreds': 1, 'plus': 4, 'to…': 18, 'via': 17, 'natively': 1, 'you…': 3, "i'll": 4, 'igtv ...
# 1579
# {'data': 1, 'the': 2, 'a': 3, 'to': 4, 'big': 5, 'science': 6, 'is': 7, 'and': 8, 'in': 9, 'of': 10, 'i': 11, 'for': 12, 'you': 13, 'on': 14, 'with': 15, 'my': 16, 'just': 17, 'that': 18, 'fart': 19, 'at': 20, 'it': 21, 'be': 22, 'are': 23, 'this': 24, 'can': 25, 'by': 26, 'about': 27, 'have': 28, 'your': 29, 'we': 30, 'poo': 31, 'like': 32, 'diarrhea': 33, 'me': 34, 'as': 35, 'all': 36, 'what': 37, 'was': 38, 'will': 39, 'some': 40, 'our': 41, 'not': 42, 'learning': 43, 'an': 44, 'from': 45, 'so': 46, 'new': 47, 'amp': 48, 'how': 49, 'do': 50, 'but': 51, 'if': 52, '1': 53, 'get': 54, 'time': 55, 'or': 56, '…': 57, 'love': 58, 'green': 59, 'ai': 60, 'know': 61, 'dog': 62, 'who': 63, 'bigdata': 64, 'they': 65, 'more': 66, '2': 67, '2020': 68, 'one': 69, 'job': 70, 'constipation': 71, 'am': 72, 'has': 73, 'now': 74, 'machine': 75, 'good': 76, 'day': 77, 'furniture': 78, 'did': 79, 'see': 80, 'people': 81, 'when': 82, "i'm": 83, 'work': 84, 'python': 85, "it's": 86, 'using': 87, '3': 88, 'courses': 89, 'find': 90, 'their': 91, 'first': 92, 'turd': 93, 'need': 94, 'hey': 95, 'analytics': 96, 'very': 97, 'after': 98, 'any': 99, 'us': 100, 'his': 101, 'out': 102, 'too': 103, 'use': 104, 'think': 105, 'poem': 106, 'inspired': 107, 'marketing': 108, 'would': 109, 'want': 110, 'bigram': 111, 'up': 112, 'been': 113, 'looking': 114, 'name': 115, 'last': 116, 'datascience': 117, 'great': 118, 'learn': 119, 'solution': 120, 'he': 121, 'only': 122, 'today': 123, 'make': 124, 'world': 125, 'which': 126, 'next': 127, 'tech': 128, "don't": 129, 'year': 130, 'why': 131, 'should': 132, 'business': 133, 'over': 134, 'intelligence': 135, '4': 136, 'oh': 137, 'doing': 138, 'no': 139, 'research': 140, 'got': 141, 'much': 142, 'sic': 143, 'really': 144, 'had': 145, 'does': 146, '10': 147, '5': 148, 'could': 149, 'started': 150, 'artificial': 151, 'prototype': 152, 'collecting': 153, 'thing': 154, 'technology': 155, "i've": 156, 'at…': 157, 'being': 158, 'way': 159, 'there': 160, 'well': 161, 'link': 162, 'career': 163, 'many': 164, 't…': 165, 'to…': 166, 'where': 167, 'top': 168, 'help': 169, 'because': 170, 'them': 171, 'real': 172, 'look': 173, 'these': 174, 'take': 175, 'via': 176, 'born': 177, 'studio': 178, 'bas': 179, 'sala': 180, 'studiobassala': 181, 'digital': 182, 'colleting': 183, 'dutch': 184, 'designweek': 185, 'visitors': 186, 'course': 187, 'working': 188, 'twitter': 189, 'google': 190, 'go': 191, 'likes': 192, 'cloud': 193, 'cat': 194, 'butt': 195, 'interested': 196, 'bio': 197, 'years': 198, 'may': 199, 'must': 200, 'its': 201, '100daysofcode': 202, 'i’m': 203, 'play': 204, 'better': 205, 'then': 206, 'things': 207, 'conference': 208, 'w…': 209, 'through': 210, 'used': 211, 'might': 212, 'never': 213, 'future': 214, 'bad': 215, 'hiring': 216, 'skills': 217, 'show': 218, 'days': 219, 'id': 220, 'most': 221, 'social': 222, 'sad': 223, 'anyone': 224, 'r': 225, 'wan': 226, 'include': 227, 'click': 228, 'project': 229, 'off': 230, 'book': 231, 'jut': 232, 'every': 233, 'i…': 234, 'f…': 235, 'read': 236, 'school': 237, 'problem': 238, 'even': 239, '6': 240, 'horse': 241, 'before': 242, 's…': 243, 'feces': 244, 'd…': 245, 'week': 246, 'hello': 247, 'company': 248, 'jet': 249, 'back': 250, 'say': 251, 'right': 252, 'power': 253, 'reading': 254, 'having': 255, 'mining': 256, 'please': 257, 'media': 258, 'set': 259, 'own': 260, '2014': 261, 'pee': 262, 'bowel': 263, 'clown': 264, 'into': 265, 'y': 266, 'online': 267, 'win': 268, 'data…': 269, 'trying': 270, 'those': 271, 'b…': 272, 'team': 273, 'start': 274, 'while': 275, 'ice': 276, 'excited': 277, 'give': 278, 'life': 279, 'man': 280, 'everyone': 281, 'a…': 282, 'without': 283, "didn't": 284, 'analysis': 285, 'called': 286, 'math': 287, 'relevant': 288, 'management': 289, 'universities': 290, 'chicken': 291, 'in…': 292, 'instead': 293, 'underwear': 294, 'best': 295, 'ml': 296, 'class': 297, 'hear': 298, 'platform': 299, 'cyber': 300, 'jobs': 301, 'long': 302, 'found': 303, 'point': 304, 'lea ...

# %%
print('Found %s unique tokens.' % len(t.word_index))
# Out:
# Found 6446 unique tokens.

# %%
def get_sequence_of_tokens(corpus):
    t.fit_on_texts(corpus)
    total_words = len(t.word_index) + 1
    
    input_sequences = []
    for line in corpus:
        token_list = t.texts_to_sequences([line])[0]
        for i in range(1, len(token_list)):
            n_gram_sequence = token_list[:i+1]
            input_sequences.append(n_gram_sequence)
            
    return input_sequences, total_words
input_sequences, total_words = get_sequence_of_tokens(tweets)

# %%
input_sequences[:10]
# Out:
# [[2512, 112],
#  [2512, 112, 4],
#  [2512, 112, 4, 3],
#  [2512, 112, 4, 3, 366],
#  [2512, 112, 4, 3, 366, 45],
#  [2512, 112, 4, 3, 366, 45, 3],
#  [2512, 112, 4, 3, 366, 45, 3, 1],
#  [2512, 112, 4, 3, 366, 45, 3, 1, 6],
#  [2512, 112, 4, 3, 366, 45, 3, 1, 6, 522],
#  [2512, 112, 4, 3, 366, 45, 3, 1, 6, 522, 324]]

# %%
# pad sequences 
def generate_padded_sequences(input_sequences):
    max_sequence_len = max([len(x) for x in input_sequences])
    input_sequences = np.array(pad_sequences(input_sequences, maxlen = max_sequence_len, padding = 'pre'))
    predictors, label = input_sequences[:,:-1],input_sequences[:,-1]
    label = ku.to_categorical(label, num_classes = total_words)
    
    return predictors, label, max_sequence_len

predictors, label, max_sequence_len = generate_padded_sequences(input_sequences)

# %%
model = Sequential()
model.add(Embedding(total_words, 10, input_length=max_sequence_len - 1))
model.add(LSTM(100))
model.add(Dropout(0.1))

model.add(Dense(total_words, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
#filepath = "model_weights_saved.hdf5"
#checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
#desired_callbacks = [checkpoint]

# %%
model.fit(predictors, label, epochs=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-c5c66a80c3c7> in <module>
# ----> 1 model.fit(predictors, label, epochs=10)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1152             sample_weight=sample_weight,
#    1153             class_weight=class_weight,
# -> 1154             batch_size=batch_size)
#    1155
#    1156         # Prepare validation data.
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     502             # to match the value shapes.
#     503             if not self.inputs:
# --> 504                 self._set_inputs(x)
#     505
#     506         if y is not None:
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in _set_inputs(self, inputs, outputs, training)
#     414                 assert len(inputs) == 1
#     415                 inputs = inputs[0]
# --> 416             self.build(input_shape=(None,) + inputs.shape[1:])
#     417             return
#     418
#
# ~\Anaconda3\lib\site-packages\keras\engine\sequential.py in build(self, input_shape)
#     220             self.inputs = [x]
#     221             for layer in self._layers:
# --> 222                 x = layer(x)
#     223             self.outputs = [x]
#     224             self._build_input_shape = input_shape
#
# ~\Anaconda3\lib\site-packages\keras\layers\recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     539
#     540         if initial_state is None and constants is None:
# --> 541             return super(RNN, self).__call__(inputs, **kwargs)
#     542
#     543         # If any of `initial_state` or `constants` are specified and are Keras
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\keras\engine\base_layer.py in __call__(self, inputs, **kwargs)
#     444                 # Raise exceptions in case the input is not compatible
#     445                 # with the input_spec specified in the layer constructor.
# --> 446                 self.assert_input_compatibility(inputs)
#     447
#     448                 # Collect input shapes to build layer.
#
# ~\Anaconda3\lib\site-packages\keras\engine\base_layer.py in assert_input_compatibility(self, inputs)
#     340                                      self.name + ': expected ndim=' +
#     341                                      str(spec.ndim) + ', found ndim=' +
# --> 342                                      str(K.ndim(x)))
#     343             if spec.max_ndim is not None:
#     344                 ndim = K.ndim(x)
#
# ValueError: Input 0 is incompatible with layer lstm_3: expected ndim=3, found ndim=2

# %%
filename = "word_vec_model_weights_saved.hdf5"
model.save_weights(filename)
print("saved model weights")
# Out:
# saved model weights

# %%
def generate_text(seed_text, next_words, model, max_seq_len):
    for _ in range(next_words):
        token_list = t.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_seq_len-1, padding='pre')
        
        predicted = model.predict_classes(token_list, verbose=0)
        
        output_word = ''
        
        for word,index in t.word_index.items():
            if index == predicted:
                output_word = word
                break
                
        seed_text = seed_text + " " + output_word
        
    return seed_text.title()

# %%
print(generate_text("this project", 20, model, max_sequence_len))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-1c3dbc5faf38> in <module>
# ----> 1 print(generate_text("this project", 20, model, max_sequence_len))
#
# <ipython-input-43-dd1ab79c1801> in generate_text(seed_text, next_words, model, max_seq_len)
#       4         token_list = pad_sequences([token_list], maxlen=max_seq_len-1, padding='pre')
#       5
# ----> 6         predicted = model.predict_classes(token_list, verbose=0)
#       7
#       8         output_word = ''
#
# ~\Anaconda3\lib\site-packages\keras\engine\sequential.py in predict_classes(self, x, batch_size, verbose)
#     266             A numpy array of class predictions.
#     267         """
# --> 268         proba = self.predict(x, batch_size=batch_size, verbose=verbose)
#     269         if proba.shape[-1] > 1:
#     270             return proba.argmax(axis=-1)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1439
#    1440         # Case 2: Symbolic tensors or Numpy array-like.
# -> 1441         x, _, _ = self._standardize_user_data(x)
#    1442         if self.stateful:
#    1443             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     563             # Case: symbolic-mode subclassed network.
#     564             # Do not do shape validation.
# --> 565             feed_input_names = self._feed_input_names
#     566             feed_input_shapes = None
#     567         else:
#
# AttributeError: 'Sequential' object has no attribute '_feed_input_names'
